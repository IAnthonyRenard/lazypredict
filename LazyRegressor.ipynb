# %% [markdown]
# # Regression - LazyRegressor par Anthony RENARD 🦊

# %%
from lazypredict.Supervised import LazyRegressor  # Utilisez LazyRegressor pour la régression
from sklearn.datasets import load_diabetes  # Importez le jeu de données de régression de votre choix
from sklearn.model_selection import train_test_split
from tabulate import tabulate

def load_data():
    data = load_diabetes()  # Remplacez load_diabetes() par le chargement de votre propre jeu de données
    X = data.data
    y = data.target
    return X, y

def train_test_split_data(X, y, test_size=0.5, random_state=123):
    return train_test_split(X, y, test_size=test_size, random_state=random_state)

def display_results(models):
    print(tabulate(models, headers='keys', tablefmt='pretty'))

def main():
    # Chargement des données de régression
    X, y = load_data()

    # Division des données en ensembles d'entraînement et de test
    X_train, X_test, y_train, y_test = train_test_split_data(X, y)

    # Initialisation du modèle LazyRegressor
    clf = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)

    # Entraînement du modèle et obtention des prédictions
    models, predictions = clf.fit(X_train, X_test, y_train, y_test)

    # Affichage des résultats sous forme de tableau
    display_results(models)

if __name__ == "__main__":
    main()
# Out:
# 100%|██████████| 42/42 [00:02<00:00, 20.93it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000066 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 440
# [LightGBM] [Info] Number of data points in the train set: 221, number of used features: 10
# [LightGBM] [Info] Start training from score 155.221719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
